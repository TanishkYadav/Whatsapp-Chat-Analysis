# %%
import re
import pandas as pd

# %%
f = open('WhatsApp Chat with Rajeev Yadav.txt','r',encoding='utf-8')

# %%
data = f.read()

# %%
print(data)
# Out:
# 16/09/2019, 10:50 am - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 16/09/2019, 10:50 am - Tanish: Hiiiiiiiiiii🥰🥰🥰🥰🥰
# 16/09/2019, 10:51 am - Rajeev Yadav: <Media omitted>
# 16/09/2019, 10:51 am - Rajeev Yadav: <Media omitted>
# 16/09/2019, 10:51 am - Rajeev Yadav: <Media omitted>
# 16/09/2019, 10:51 am - Rajeev Yadav: <Media omitted>
# 16/09/2019, 10:51 am - Rajeev Yadav: <Media omitted>
# 16/09/2019, 10:51 am - Rajeev Yadav: <Media omitted>
# 16/09/2019, 10:51 am - Rajeev Yadav: <Media omitted>
# 16/09/2019, 10:51 am - Rajeev Yadav: <Media omitted>
# 16/09/2019, 10:51 am - Rajeev Yadav: <Media omitted>
# 16/09/2019, 10:51 am - Rajeev Yadav: <Media omitted>
# 16/09/2019, 10:51 am - Rajeev Yadav: <Media omitted>
# 16/09/2019, 10:51 am - Rajeev Yadav: <Media omitted>
# 16/09/2019, 10:51 am - Rajeev Yadav: <Media omitted>
# 16/09/2019, 10:51 am - Rajeev Yadav: <Media omitted>
# ...

# %%
print(type(data))
# Out:
# <class 'str'>

# %%
 pattern = '\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s[APap][mM]\s-\s'

# %%
messages = re.split(pattern,data)[1:]
messages
# Out:
# ['Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n',
#  'Tanish: Hiiiiiiiiiii🥰🥰🥰🥰🥰\n',
#  'Rajeev Yadav: <Media omitted>\n',
#  'Rajeev Yadav: <Media omitted>\n',
#  'Rajeev Yadav: <Media omitted>\n',
#  'Rajeev Yadav: <Media omitted>\n',
#  'Rajeev Yadav: <Media omitted>\n',
#  'Rajeev Yadav: <Media omitted>\n',
#  'Rajeev Yadav: <Media omitted>\n',
#  'Rajeev Yadav: <Media omitted>\n',
#  'Rajeev Yadav: <Media omitted>\n',
#  'Rajeev Yadav: <Media omitted>\n',
#  'Rajeev Yadav: <Media omitted>\n',
#  'Rajeev Yadav: <Media omitted>\n',
#  'Rajeev Yadav: <Media omitted>\n',
#  'Rajeev Yadav: <Media omitted>\n',
#  'Rajeev Yadav: <Media omitted>\n',
#  'Rajeev Yadav: <Media omitted>\n',
#  'Rajeev Yadav: <Media omitted>\n',
#  'Tanish: Bhey notes\n',
#  'Rajeev Yadav: Notes nahi\n',
#  'Tanish: Bhejo\n',
#  'Rajeev Yadav: Book ka\n',
#  'Tanish: Haa wahi\n',
#  'Rajeev Yadav: Hi hai\n',
# ...

# %%
dates = re.findall(pattern,data)
dates
# Out:
# ['16/09/2019, 10:50 am - ',
#  '16/09/2019, 10:50 am - ',
#  '16/09/2019, 10:51 am - ',
#  '16/09/2019, 10:51 am - ',
#  '16/09/2019, 10:51 am - ',
#  '16/09/2019, 10:51 am - ',
#  '16/09/2019, 10:51 am - ',
#  '16/09/2019, 10:51 am - ',
#  '16/09/2019, 10:51 am - ',
#  '16/09/2019, 10:51 am - ',
#  '16/09/2019, 10:51 am - ',
#  '16/09/2019, 10:51 am - ',
#  '16/09/2019, 10:51 am - ',
#  '16/09/2019, 10:51 am - ',
#  '16/09/2019, 10:51 am - ',
#  '16/09/2019, 10:51 am - ',
#  '16/09/2019, 10:51 am - ',
#  '16/09/2019, 10:51 am - ',
#  '16/09/2019, 10:51 am - ',
#  '07/11/2019, 8:38 pm - ',
#  '07/11/2019, 8:38 pm - ',
#  '07/11/2019, 8:38 pm - ',
#  '07/11/2019, 8:38 pm - ',
#  '07/11/2019, 8:39 pm - ',
#  '07/11/2019, 8:39 pm - ',
#  '07/11/2019, 8:40 pm - ',
#  '07/11/2019, 8:40 pm - ',
#  '07/11/2019, 8:41 pm - ',
#  '07/11/2019, 8:41 pm - ',
#  '07/11/2019, 8:44 pm - ',
#  '07/11/2019, 8:44 pm - ',
#  '07/11/2019, 8:44 pm - ',
#  '07/11/2019, 8:44 pm - ',
# ...

# %%
df = pd.DataFrame({'user_message': messages, 'message_date': dates})

df['message_date'] = pd.to_datetime(df['message_date'],format='%d/%m/%Y, %I:%M %p - ')

df.rename(columns={'message_date': 'date'}, inplace = True)

df.head()
# Out:
#                                         user_message                date
# 0  Messages and calls are end-to-end encrypted. N... 2019-09-16 10:50:00
# 1                        Tanish: Hiiiiiiiiiii🥰🥰🥰🥰🥰\n 2019-09-16 10:50:00
# 2                    Rajeev Yadav: <Media omitted>\n 2019-09-16 10:51:00
# 3                    Rajeev Yadav: <Media omitted>\n 2019-09-16 10:51:00
# 4                    Rajeev Yadav: <Media omitted>\n 2019-09-16 10:51:00

# %%
users = []
messages = []
for message in df['user_message']:
    entry = re.split('([\w\W]+?):\s',message)
    if entry[1:]:
        users.append(entry[1])
        messages.append(entry[2])
    else:
        users.append('group_notification')
        messages.append(entry[0])
        
df['user'] = users
df['message'] = messages
df.drop(columns=['user_message'],inplace=True)

df.head()
# Out:
#                  date                user  \
# 0 2019-09-16 10:50:00  group_notification
# 1 2019-09-16 10:50:00              Tanish
# 2 2019-09-16 10:51:00        Rajeev Yadav
# 3 2019-09-16 10:51:00        Rajeev Yadav
# 4 2019-09-16 10:51:00        Rajeev Yadav
#
#                                              message
# 0  Messages and calls are end-to-end encrypted. N...
# 1                                Hiiiiiiiiiii🥰🥰🥰🥰🥰\n
# 2                                  <Media omitted>\n
# 3                                  <Media omitted>\n
# 4                                  <Media omitted>\n

# %%
df['year'] = df['date'].dt.year

# %%
df.head()
# Out:
#                  date                user  \
# 0 2019-09-16 10:50:00  group_notification
# 1 2019-09-16 10:50:00              Tanish
# 2 2019-09-16 10:51:00        Rajeev Yadav
# 3 2019-09-16 10:51:00        Rajeev Yadav
# 4 2019-09-16 10:51:00        Rajeev Yadav
#
#                                              message  year
# 0  Messages and calls are end-to-end encrypted. N...  2019
# 1                                Hiiiiiiiiiii🥰🥰🥰🥰🥰\n  2019
# 2                                  <Media omitted>\n  2019
# 3                                  <Media omitted>\n  2019
# 4                                  <Media omitted>\n  2019

# %%
df['month'] = df['date'].dt.month_name()

# %%
df['day'] = df['date'].dt.day

# %%
df['hour'] = df['date'].dt.hour

# %%
df['minute'] = df['date'].dt.minute

# %%
df.head()
# Out:
#                  date                user  \
# 0 2019-09-16 10:50:00  group_notification
# 1 2019-09-16 10:50:00              Tanish
# 2 2019-09-16 10:51:00        Rajeev Yadav
# 3 2019-09-16 10:51:00        Rajeev Yadav
# 4 2019-09-16 10:51:00        Rajeev Yadav
#
#                                              message  year      month  day  \
# 0  Messages and calls are end-to-end encrypted. N...  2019  September   16
# 1                                Hiiiiiiiiiii🥰🥰🥰🥰🥰\n  2019  September   16
# 2                                  <Media omitted>\n  2019  September   16
# 3                                  <Media omitted>\n  2019  September   16
# 4                                  <Media omitted>\n  2019  September   16
#
#    hour  minute
# 0    10      50
# 1    10      50
# 2    10      51
# 3    10      51
# 4    10      51

# %%
words = []
for message in df['message']:
    words.extend(message.split())

# %%
len(words)
# Out:
# 5476

# %%
pip install urlextract
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.1 is available.
# You should consider upgrading via the 'C:\Users\lenovo\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
from urlextract import URLExtract

extractor = URLExtract() 
urls = extractor.find_urls(' Lets www.gmail.com have URL stackoverflow.com as an example google.com')
urls
# Out:
# ['www.gmail.com', 'stackoverflow.com', 'google.com']

# %%
links = []

for message in df['message']:
    links.extend(extractor.find_urls(message))

# %%
links
# Out:
# ['https://maps.app.goo.gl/EWmvSP5GLQwqrVBW9',
#  'https://maps.app.goo.gl/gySAhd4zFTeK55Db9',
#  'https://pediaa.com/difference-between-management-information-system-and-decision-support-system/',
#  'http://exam.vbspu.ac.in/nresult/EvenSemesterResult2017_2018/viewResult',
#  'https://share.pbgcj.com/h5campaign.php?cdn=2&gameid=1320&image=s/pubgmobile/cp/a20200106preheat/share_en.png&title=Carlo%20will%20join%20the%20battle%20on%203%2F4%21&descript=Complete%20Hunt%20Missions%20and%20get%20clues%20about%20Carlo.&module=1010000&uid=5651338880&src=whatsapp&adjust_t=xxry36_6dp6z9&adjust_deeplink=igame1320%3A%2F%2Fmodule%3D1010000%26uid%3D5651338880%26src%3Dwhatsapp&adjust_campaign=h5_a20200106preheat&region=gl',
#  'https://www.geeksforgeeks.org/process-schedulers-in-operating-system/amp/',
#  'https://www.programiz.com/java-programming/class-objects',
#  'https://youtube.com/playlist?list=PLaW_Y-ZbTGeSgqMOXlAqQMebnGemBg8UY',
#  'https://www.programiz.com/java-programming',
# ...

# %%
x = df['user'].value_counts().head()

# %%
import matplotlib.pyplot as plt

# %%
name = x.index
count = x.values

# %%
plt.bar(name,count)
plt.xticks(rotation='vertical')
plt.show()

# %%
round((df['user'].value_counts()/df.shape[0])*100,2).reset_index().rename(columns={'index':'name','user':'percent'})
# Out:
#                  name  percent
# 0        Rajeev Yadav    61.19
# 1              Tanish    38.73
# 2  group_notification     0.07

# %%
words = []

for message in df['message']:
    words.extend(message.split())

# %%
from collections import Counter
pd.DataFrame(Counter(words).most_common(20))
# Out:
#            0    1
# 0     <Media  259
# 1   omitted>  259
# 2        hai  145
# 3          h  127
# 4         ho   87
# 5         to   75
# 6        say   60
# 7        nhi   57
# 8        bhi   55
# 9         hu   54
# 10        ka   43
# 11        ki   43
# 12        Ha   39
# 13       Haa   38
# 14        hi   38
# 15      nahi   34
# 16       may   33
# 17        na   33
# 18        kr   33
# 19        ko   32
